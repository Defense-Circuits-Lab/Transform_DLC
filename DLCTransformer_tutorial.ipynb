# %%
from DLCTransformer import DLCTransformer

# %%
dlc_filepath = r"PATH_TO_DLC_FILE\dlc_output.h5"
config_filepath = r"PATH_TO_CONFIG_FILE\config.yaml"
transformer = DLCTransformer(dlc_filepath=dlc_filepath, config_filepath=config_filepath)

# %%
scaled = transformer.run()
# Out:
# Angle between basis vectors : 89.02206319831454

# %%
scaled.head()
# Out:
# scorer    DLC_resnet50_rotarodApr12shuffle1_1030000                       \
# bodyparts                             RodUpperRight
# coords                                            x         y likelihood
# 0                                          5.802010  2.999461   0.999942
# 1                                          5.803023  3.004901   0.997339
# 2                                          5.860810  3.012999   0.999323
# 3                                          5.847352  3.005848   0.998869
# 4                                          5.847999  2.960746   0.998739
#
# scorer                                                                 \
# bodyparts RodLowerRight                      MiddleBarRight
# coords                x         y likelihood              x         y
# 0              5.789377  0.041722   0.999951       5.024163 -0.713756
# 1              5.784513  0.035238   0.999161       5.017323 -0.718355
# 2              5.818135  0.023267   0.999150       5.055795 -0.706361
# 3              5.743407  0.034727   0.999873       5.014968 -0.721586
# 4              5.824998 -0.016177   0.999312       5.077752 -0.763708
#
# scorer                             ...                                 \
# bodyparts            RodUpperLeft  ...    HipLeft     Snout
# coords    likelihood            x  ... likelihood         x         y
# 0           0.999995    -0.000099  ...   0.997812  5.543689  3.670966
# 1           0.999996    -0.046996  ...   0.994883  4.337817  6.420704
# 2           0.999992    -0.013021  ...   0.996399  1.082394  4.153106
# 3           0.999993    -0.067746  ...   0.517148  4.547778  5.201896
# 4           0.999988    -0.032124  ...   0.618162  1.087993  3.908506
#
# scorer                                                                   \
# bodyparts              EarLeft                       EarRight
# coords    likelihood         x         y likelihood         x         y
# 0           0.000445  1.055960  4.706717   0.188992  4.793166  6.167059
# 1           0.000692  1.124530  4.661069   0.257247  4.774228  6.310482
# 2           0.000496  1.147447  4.715855   0.548459  1.390079  4.598634
# 3           0.003667  1.223779  5.017374   0.008410  5.319001  5.106706
# 4           0.000866  1.133342  4.544412   0.057824  5.513124  4.796401
#
# scorer
# bodyparts
# coords    likelihood
# 0           0.000760
# 1           0.004722
# 2           0.001259
# 3           0.022830
# 4           0.008091
#
# [5 rows x 75 columns]
